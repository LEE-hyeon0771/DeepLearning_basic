# %% [markdown]
# ## 오버피팅 일으키기

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.07333333333333333, test acc:0.0777
# epoch:1, train acc:0.08666666666666667, test acc:0.0875
# epoch:2, train acc:0.11333333333333333, test acc:0.0993
# epoch:3, train acc:0.13333333333333333, test acc:0.119
# epoch:4, train acc:0.16333333333333333, test acc:0.1421
# epoch:5, train acc:0.21666666666666667, test acc:0.156
# epoch:6, train acc:0.22666666666666666, test acc:0.1732
# epoch:7, train acc:0.25333333333333335, test acc:0.186
# epoch:8, train acc:0.26, test acc:0.1937
# epoch:9, train acc:0.27666666666666667, test acc:0.2068
# epoch:10, train acc:0.30333333333333334, test acc:0.218
# epoch:11, train acc:0.30666666666666664, test acc:0.224
# epoch:12, train acc:0.31333333333333335, test acc:0.2274
# epoch:13, train acc:0.33, test acc:0.2444
# epoch:14, train acc:0.3333333333333333, test acc:0.2569
# epoch:15, train acc:0.33, test acc:0.2581
# epoch:16, train acc:0.37, test acc:0.2784
# epoch:17, train acc:0.36666666666666664, test acc:0.2761
# epoch:18, train acc:0.36666666666666664, test acc:0.2786
# epoch:19, train acc:0.38666666666666666, test acc:0.2925
# epoch:20, train acc:0.4266666666666667, test acc:0.3073
# epoch:21, train acc:0.43, test acc:0.3103
# epoch:22, train acc:0.4266666666666667, test acc:0.3108
# epoch:23, train acc:0.48, test acc:0.3521
# epoch:24, train acc:0.48, test acc:0.3567
# epoch:25, train acc:0.49, test acc:0.3872
# epoch:26, train acc:0.49333333333333335, test acc:0.3879
# epoch:27, train acc:0.5233333333333333, test acc:0.4044
# epoch:28, train acc:0.5266666666666666, test acc:0.4192
# epoch:29, train acc:0.53, test acc:0.4275
# epoch:30, train acc:0.54, test acc:0.4352
# epoch:31, train acc:0.5466666666666666, test acc:0.4342
# epoch:32, train acc:0.5533333333333333, test acc:0.4447
# epoch:33, train acc:0.5766666666666667, test acc:0.4505
# epoch:34, train acc:0.5733333333333334, test acc:0.4547
# epoch:35, train acc:0.5766666666666667, test acc:0.4616
# epoch:36, train acc:0.5866666666666667, test acc:0.4711
# epoch:37, train acc:0.6033333333333334, test acc:0.4768
# epoch:38, train acc:0.5933333333333334, test acc:0.4684
# epoch:39, train acc:0.63, test acc:0.4972
# epoch:40, train acc:0.6333333333333333, test acc:0.513
# epoch:41, train acc:0.6566666666666666, test acc:0.5253
# epoch:42, train acc:0.6633333333333333, test acc:0.5272
# epoch:43, train acc:0.6533333333333333, test acc:0.5344
# epoch:44, train acc:0.6433333333333333, test acc:0.5327
# epoch:45, train acc:0.66, test acc:0.5571
# epoch:46, train acc:0.6566666666666666, test acc:0.5618
# epoch:47, train acc:0.68, test acc:0.5735
# epoch:48, train acc:0.6933333333333334, test acc:0.5843
# epoch:49, train acc:0.6966666666666667, test acc:0.5873
# epoch:50, train acc:0.6966666666666667, test acc:0.5964
# epoch:51, train acc:0.72, test acc:0.602
# epoch:52, train acc:0.7133333333333334, test acc:0.5991
# epoch:53, train acc:0.7033333333333334, test acc:0.6069
# epoch:54, train acc:0.71, test acc:0.6116
# epoch:55, train acc:0.7266666666666667, test acc:0.6166
# epoch:56, train acc:0.73, test acc:0.6216
# epoch:57, train acc:0.73, test acc:0.6263
# epoch:58, train acc:0.72, test acc:0.6145
# epoch:59, train acc:0.74, test acc:0.6305
# epoch:60, train acc:0.7466666666666667, test acc:0.6323
# epoch:61, train acc:0.7533333333333333, test acc:0.6367
# epoch:62, train acc:0.7466666666666667, test acc:0.6419
# epoch:63, train acc:0.7633333333333333, test acc:0.6512
# epoch:64, train acc:0.7333333333333333, test acc:0.6329
# epoch:65, train acc:0.77, test acc:0.6521
# epoch:66, train acc:0.7666666666666667, test acc:0.642
# epoch:67, train acc:0.77, test acc:0.6616
# epoch:68, train acc:0.75, test acc:0.6458
# epoch:69, train acc:0.77, test acc:0.6634
# epoch:70, train acc:0.77, test acc:0.6591
# epoch:71, train acc:0.78, test acc:0.6601
# epoch:72, train acc:0.78, test acc:0.6638
# epoch:73, train acc:0.7533333333333333, test acc:0.6607
# epoch:74, train acc:0.7766666666666666, test acc:0.6676
# epoch:75, train acc:0.77, test acc:0.6689
# epoch:76, train acc:0.77, test acc:0.6654
# epoch:77, train acc:0.7733333333333333, test acc:0.6715
# epoch:78, train acc:0.7833333333333333, test acc:0.6775
# epoch:79, train acc:0.7733333333333333, test acc:0.6695
# epoch:80, train acc:0.7766666666666666, test acc:0.673
# epoch:81, train acc:0.7733333333333333, test acc:0.6734
# epoch:82, train acc:0.79, test acc:0.6723
# epoch:83, train acc:0.78, test acc:0.6765
# epoch:84, train acc:0.7866666666666666, test acc:0.6776
# epoch:85, train acc:0.7833333333333333, test acc:0.6824
# epoch:86, train acc:0.7866666666666666, test acc:0.6786
# epoch:87, train acc:0.7833333333333333, test acc:0.6814
# epoch:88, train acc:0.7733333333333333, test acc:0.6753
# epoch:89, train acc:0.7766666666666666, test acc:0.6715
# epoch:90, train acc:0.7866666666666666, test acc:0.6775
# epoch:91, train acc:0.78, test acc:0.682
# epoch:92, train acc:0.77, test acc:0.6736
# epoch:93, train acc:0.7733333333333333, test acc:0.6812
# epoch:94, train acc:0.7866666666666666, test acc:0.6838
# epoch:95, train acc:0.79, test acc:0.6749
# epoch:96, train acc:0.7933333333333333, test acc:0.6825
# epoch:97, train acc:0.7966666666666666, test acc:0.6838
# epoch:98, train acc:0.79, test acc:0.685
# epoch:99, train acc:0.79, test acc:0.6715
# epoch:100, train acc:0.7866666666666666, test acc:0.687
# epoch:101, train acc:0.7966666666666666, test acc:0.6879
# epoch:102, train acc:0.7966666666666666, test acc:0.6861
# epoch:103, train acc:0.7966666666666666, test acc:0.6905
# epoch:104, train acc:0.79, test acc:0.6791
# epoch:105, train acc:0.78, test acc:0.6843
# epoch:106, train acc:0.79, test acc:0.6883
# epoch:107, train acc:0.79, test acc:0.6892
# epoch:108, train acc:0.8, test acc:0.6877
# epoch:109, train acc:0.7966666666666666, test acc:0.694
# epoch:110, train acc:0.8, test acc:0.7009
# epoch:111, train acc:0.7933333333333333, test acc:0.6848
# epoch:112, train acc:0.7966666666666666, test acc:0.6932
# epoch:113, train acc:0.8066666666666666, test acc:0.6951
# epoch:114, train acc:0.8066666666666666, test acc:0.6942
# epoch:115, train acc:0.8066666666666666, test acc:0.6916
# epoch:116, train acc:0.8033333333333333, test acc:0.6954
# epoch:117, train acc:0.8, test acc:0.6928
# epoch:118, train acc:0.8033333333333333, test acc:0.6996
# epoch:119, train acc:0.8033333333333333, test acc:0.6928
# epoch:120, train acc:0.8133333333333334, test acc:0.6876
# epoch:121, train acc:0.8133333333333334, test acc:0.6918
# epoch:122, train acc:0.81, test acc:0.6929
# epoch:123, train acc:0.81, test acc:0.6999
# epoch:124, train acc:0.81, test acc:0.6971
# epoch:125, train acc:0.81, test acc:0.7086
# epoch:126, train acc:0.82, test acc:0.7092
# epoch:127, train acc:0.8066666666666666, test acc:0.7034
# epoch:128, train acc:0.81, test acc:0.7007
# epoch:129, train acc:0.82, test acc:0.7064
# epoch:130, train acc:0.83, test acc:0.6968
# epoch:131, train acc:0.8133333333333334, test acc:0.6973
# epoch:132, train acc:0.8166666666666667, test acc:0.7021
# epoch:133, train acc:0.8133333333333334, test acc:0.7
# epoch:134, train acc:0.8166666666666667, test acc:0.7074
# epoch:135, train acc:0.82, test acc:0.7075
# epoch:136, train acc:0.8266666666666667, test acc:0.7099
# epoch:137, train acc:0.8233333333333334, test acc:0.7073
# epoch:138, train acc:0.8233333333333334, test acc:0.7065
# epoch:139, train acc:0.8133333333333334, test acc:0.6991
# epoch:140, train acc:0.8233333333333334, test acc:0.7058
# epoch:141, train acc:0.8233333333333334, test acc:0.7108
# epoch:142, train acc:0.8233333333333334, test acc:0.7003
# epoch:143, train acc:0.8266666666666667, test acc:0.699
# epoch:144, train acc:0.8433333333333334, test acc:0.7156
# epoch:145, train acc:0.8166666666666667, test acc:0.6941
# epoch:146, train acc:0.8266666666666667, test acc:0.7075
# epoch:147, train acc:0.8333333333333334, test acc:0.7095
# epoch:148, train acc:0.8233333333333334, test acc:0.7037
# epoch:149, train acc:0.83, test acc:0.7026
# epoch:150, train acc:0.8266666666666667, test acc:0.7103
# epoch:151, train acc:0.8233333333333334, test acc:0.7025
# epoch:152, train acc:0.82, test acc:0.7069
# epoch:153, train acc:0.8166666666666667, test acc:0.7043
# epoch:154, train acc:0.8166666666666667, test acc:0.7012
# epoch:155, train acc:0.8266666666666667, test acc:0.7069
# epoch:156, train acc:0.8366666666666667, test acc:0.7037
# epoch:157, train acc:0.8333333333333334, test acc:0.7114
# epoch:158, train acc:0.8333333333333334, test acc:0.7125
# epoch:159, train acc:0.8366666666666667, test acc:0.7113
# epoch:160, train acc:0.8433333333333334, test acc:0.7085
# epoch:161, train acc:0.83, test acc:0.7027
# epoch:162, train acc:0.83, test acc:0.7034
# epoch:163, train acc:0.8366666666666667, test acc:0.714
# epoch:164, train acc:0.83, test acc:0.7121
# epoch:165, train acc:0.8366666666666667, test acc:0.7121
# epoch:166, train acc:0.8366666666666667, test acc:0.7112
# epoch:167, train acc:0.8333333333333334, test acc:0.7137
# epoch:168, train acc:0.8366666666666667, test acc:0.706
# epoch:169, train acc:0.8366666666666667, test acc:0.7092
# epoch:170, train acc:0.84, test acc:0.7078
# epoch:171, train acc:0.85, test acc:0.7102
# epoch:172, train acc:0.8466666666666667, test acc:0.7045
# epoch:173, train acc:0.84, test acc:0.7112
# epoch:174, train acc:0.83, test acc:0.7036
# epoch:175, train acc:0.8266666666666667, test acc:0.7126
# epoch:176, train acc:0.8366666666666667, test acc:0.706
# epoch:177, train acc:0.8366666666666667, test acc:0.7103
# epoch:178, train acc:0.8466666666666667, test acc:0.7131
# epoch:179, train acc:0.85, test acc:0.7136
# epoch:180, train acc:0.85, test acc:0.7119
# epoch:181, train acc:0.84, test acc:0.7029
# epoch:182, train acc:0.8466666666666667, test acc:0.7036
# epoch:183, train acc:0.8366666666666667, test acc:0.7001
# epoch:184, train acc:0.85, test acc:0.7074
# epoch:185, train acc:0.8366666666666667, test acc:0.7042
# epoch:186, train acc:0.8533333333333334, test acc:0.7125
# epoch:187, train acc:0.84, test acc:0.7087
# epoch:188, train acc:0.8333333333333334, test acc:0.7041
# epoch:189, train acc:0.8533333333333334, test acc:0.7085
# epoch:190, train acc:0.8533333333333334, test acc:0.7066
# epoch:191, train acc:0.84, test acc:0.7035
# epoch:192, train acc:0.8533333333333334, test acc:0.714
# epoch:193, train acc:0.8566666666666667, test acc:0.7176
# epoch:194, train acc:0.8366666666666667, test acc:0.7063
# epoch:195, train acc:0.8466666666666667, test acc:0.7136
# epoch:196, train acc:0.8266666666666667, test acc:0.691
# epoch:197, train acc:0.8466666666666667, test acc:0.7093
# epoch:198, train acc:0.8433333333333334, test acc:0.7009
# epoch:199, train acc:0.8533333333333334, test acc:0.7051
# epoch:200, train acc:0.84, test acc:0.7028
